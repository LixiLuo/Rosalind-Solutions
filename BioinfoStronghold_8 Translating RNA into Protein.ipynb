# %% [markdown]
# Mine

# %%
path='C:\\Users\Luo_L\Desktop\Python Examples\codon table/codon table.txt'
f=open(path)
f2=f.read().replace('\n',' ').split()

# %%
RNA=[]
Codon=[]
for n in range(len(f2)):
    if (n+1)%2==1:
        RNA.append(f2[n])
    else:
        Codon.append(f2[n])
codonlist=dict(zip(RNA,Codon))  #把两个list变成dict的方法~~#
codonlist
# Out:
# {'UUU': 'F',
#  'CUU': 'L',
#  'AUU': 'I',
#  'GUU': 'V',
#  'UUC': 'F',
#  'CUC': 'L',
#  'AUC': 'I',
#  'GUC': 'V',
#  'UUA': 'L',
#  'CUA': 'L',
#  'AUA': 'I',
#  'GUA': 'V',
#  'UUG': 'L',
#  'CUG': 'L',
#  'AUG': 'M',
#  'GUG': 'V',
#  'UCU': 'S',
#  'CCU': 'P',
#  'ACU': 'T',
#  'GCU': 'A',
#  'UCC': 'S',
#  'CCC': 'P',
#  'ACC': 'T',
#  'GCC': 'A',
#  'UCA': 'S',
#  'CCA': 'P',
#  'ACA': 'T',
#  'GCA': 'A',
#  'UCG': 'S',
#  'CCG': 'P',
#  'ACG': 'T',
#  'GCG': 'A',
#  'UAU': 'Y',
#  'CAU': 'H',
#  'AAU': 'N',
#  'GAU': 'D',
#  'UAC': 'Y',
#  'CAC': 'H',
#  'AAC': 'N',
#  'GAC': 'D',
#  'UAA': 'Stop',
#  'CAA': 'Q',
#  'AAA': 'K',
#  'GAA': 'E',
#  'UAG': 'Stop',
#  'CAG': 'Q',
#  'AAG': 'K',
#  'GAG': 'E',
#  'UGU': 'C',
#  'CGU': 'R',
#  'AGU': 'S',
#  'GGU': 'G',
#  'UGC': 'C',
#  'CGC': 'R',
#  'AGC': 'S',
#  'GGC': 'G',
#  'UGA': 'Stop',
#  'CGA': 'R',
#  'AGA': 'R',
#  'GGA': 'G',
#  'UGG': 'W',
#  'CGG': 'R',
#  'AGG': 'R',
#  'GGG': 'G'}

# %%
seq='AUGGCCAUGGCGCCCAGAACUGAGAUCAAUAGUACCCGUAUUAACGGGUGA'
seq1='...'

# %%
import numpy as np
Rna=[]
for n in np.arange(0,len(seq),3):
    rna=seq[n:n+3]
    Rna.append(rna)
Rna
# Out:
# ['AUG',
#  'GCC',
#  'AUG',
#  'GCG',
#  'CCC',
#  'AGA',
#  'ACU',
#  'GAG',
#  'AUC',
#  'AAU',
#  'AGU',
#  'ACC',
#  'CGU',
#  'AUU',
#  'AAC',
#  'GGG',
#  'UGA']

# %%
translation=[]
for i in Rna:
    trans=codonlist[i]
    translation.append(trans)
translation
# Out:
# ['M',
#  'A',
#  'M',
#  'A',
#  'P',
#  'R',
#  'T',
#  'E',
#  'I',
#  'N',
#  'S',
#  'T',
#  'R',
#  'I',
#  'N',
#  'G',
#  'Stop']

# %%
x=translation
x.remove('Stop')
x
# Out:
# ['M',
#  'A',
#  'M',
#  'A',
#  'P',
#  'R',
#  'T',
#  'E',
#  'I',
#  'N',
#  'S',
#  'T',
#  'R',
#  'I',
#  'N',
#  'G']

# %%
print(''.join(x))
# Out:
# MAMAPRTEINSTRING

# %% [markdown]
# Rosalind:

# %%
string = """UUU F      CUU L      AUU I      GUU V
UUC F      CUC L      AUC I      GUC V
UUA L      CUA L      AUA I      GUA V
UUG L      CUG L      AUG M      GUG V
UCU S      CCU P      ACU T      GCU A
UCC S      CCC P      ACC T      GCC A
UCA S      CCA P      ACA T      GCA A
UCG S      CCG P      ACG T      GCG A
UAU Y      CAU H      AAU N      GAU D
UAC Y      CAC H      AAC N      GAC D
UAA Stop   CAA Q      AAA K      GAA E
UAG Stop   CAG Q      AAG K      GAG E
UGU C      CGU R      AGU S      GGU G
UGC C      CGC R      AGC S      GGC G
UGA Stop   CGA R      AGA R      GGA G
UGG W      CGG R      AGG R      GGG G"""

coded = "AUGGCCAUGGCGCCCAGAACUGAGAUCAAUAGUACCCGUAUUAACGGGUGA"
decoded = ''

traL =  string.split()
traDict = dict(zip(traL[0::2], traL[1::2])) #比我的办法聪明多了!!!#

for i in range(0, len(coded)-3, 3):    #len-3直接去掉了'Stop'
    decoded += traDict[coded[i:i+3]]

print(decoded)
# Out:
# MAMAPRTEINSTRING

# %% [markdown]
# Rosalind有一小段值得参考，以用于解决stop，当然可以用换行等代替：

# %%
import re
codonsTable = open(path).read()
codons_to_aa = {c:a for c,a in [s.strip(' ').split(' ')
            for s in re.findall('\S\S\S \S',codonsTable)]}
for c in 'UAA','UAG','UGA':
    codons_to_aa[c]=''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4e02a1f39d72> in <module>
#       1 import re
# ----> 2 codonsTable = open(path).read()
#       3 codons_to_aa = {c:a for c,a in [s.strip(' ').split(' ')
#       4             for s in re.findall('\S\S\S \S',codonsTable)]}
#       5 for c in 'UAA','UAG','UGA':
#
# NameError: name 'path' is not defined
